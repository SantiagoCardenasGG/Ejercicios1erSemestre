# %% [markdown]
# EJERCICIO 1

# %%
#Declaracion de variables
angulo=0.0
var_angulo=''

# %%
angulo=float(input('Digite el angulo del : '))
# Out:
# Digite el angulo del : 80

# %%
if(angulo<90):
  var_angulo = 'Es un angulo agudo'
if(angulo>90):
  var_angulo = 'Es un angulo obtuso'
if(angulo==90):
  var_angulo = 'Es un angulo recto'

# %%
print('Angulo:',var_angulo)
# Out:
# Angulo: Es un angulo agudo
