# %%
def mostrar_mensaje():
  print("**************************************************")
  print("Funcion que no recibe parametro y no retorna valor")
  print("Linea dos mensajes")
  print("**************************************************")

mostrar_mensaje()
# Out:
# **************************************************
# Funcion que no recibe parametro y no retorna valor
# Linea dos mensajes
# **************************************************

# %%
def sumatoria(n):
    s=0
    for i in range(n):
      s=s+pow(i,2)
    print("la sumatoria es: ",s)

sumatoria(5)
# Out:
# la sumatoria es:  30
